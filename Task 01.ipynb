# %%
from __future__ import division, print_function, unicode_literals

# %%
import numpy as np

# %%
random_array = np.random.exponential(scale=1.0, size=(4, 4))
print(random_array)
# Out:
# [[0.42903215 0.99116525 0.69326278 2.21457173]
#  [0.31123411 2.18968293 0.82907026 1.89558874]
#  [1.14289013 0.98717241 0.24788443 0.12617221]
#  [0.25833594 0.7636188  0.18820573 0.95411789]]

# %%
import matplotlib.pyplot as plt

exp_data = np.random.exponential(scale=1.0, size=100000)
uniform_data = np.random.rand(100000)
normal_data = np.random.randn(100000)

plt.hist(exp_data, density=True, bins=100, histtype="step", color="red", label="exponential")
plt.hist(uniform_data, density=True, bins=100, histtype="step", color="blue", label="uniform")
plt.hist(normal_data, density=True, bins=100, histtype="step", color="green", label="normal")

plt.legend(loc="upper right")
plt.title("Random distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()

# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv('Pokemon.csv')

corr_pearson = df.corr(method='pearson')
corr_spearman = df.corr(method='spearman')

plt.figure(figsize=(10, 8))
sns.heatmap(corr_pearson, annot=True, cmap='coolwarm', center=0)
plt.title('Pearson Correlation')
plt.show()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_spearman, annot=True, cmap='coolwarm', center=0)
plt.title('Spearman Rank Correlation')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import pandas as pd
#       4 # Assuming df is the DataFrame containing the features
# ----> 5 corr_pearson = df.corr(method='pearson')
#       6 corr_spearman = df.corr(method='spearman')
#       8 plt.figure(figsize=(10, 8))
#
# NameError: name 'df' is not defined
